# %% [markdown]
# <h1><center>Universidad de los Andes ‐ Ciencia de datos aplicada
#  </center>
#     <h1><center>Sprint 2: Dataset Udemy </center></h1>
# <h1><center>Ana María Montes Franco - 202010396 </center><h1>

# %% [markdown]
# ## Context of the problem
#
# Udemy is a
#
# > ### Features in the DataFrame:
# >> 1. course_id: Course identification number
# >> 2. course_title: Title of course
# >> 3. url: Course URL
# >> 4. is_paid: True if the course costs money, false if the course is free
# >> 5. price: Price of course
# >> 6. num_subscribers: Number of subscribers for the course
# >> 7. num_lectures: Number of lectures in the course
# >> 8. num_reviews
# >> 10. level: Difficulty level of the course
# >> 11. content_duration: Duration of all course materials
# >> 12. published_timestamp: Course publication date
# >> 13. subject: Subject of course

# %%
# Librerias 
import numpy as np
#Librería de manejo de datos
import pandas as pd
#Para regresión 
from sklearn import linear_model as lm
from sklearn.linear_model import LinearRegression
# Para realizar la separación del conjunto de aprendizaje en entrenamiento y test.
from sklearn.model_selection import train_test_split

# Grid search para obtener los mejores hiperparámetros
from sklearn.model_selection import GridSearchCV
# Para la validación cruzada
from sklearn.model_selection import KFold 

#Preprocesar
from sklearn import preprocessing

# Para determinar el rendimiento del modelo con las métricas MSE, MAE y R2
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
# Para sacar un reporte estadístico que podemos usar para determinar las importancia de las variables explicativas.
import statsmodels.api as sm 

# Librerías para gráficos
import matplotlib.pyplot as plt
import seaborn as sns
#Pandas profiling 
from pandas_profiling import ProfileReport

# %%
#### Lo que se quiere es que más personas vean el contenido, 
## Que la duración sea lo suficientemente buena para capturar las personas, general más views para los cursos
## al tener más views se tengan más recomendaciones para otras sistema y los puedan redirigir a sus cursos 
## Campañas de fidelización

# %%
ucourses=pd.read_csv('udemy_courses.csv',encoding='latin-1',sep=',')
ucourses.head(5)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
ucourses.shape
# Out:
# (3678, 12)

# %%
ucourses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   object
#  11  subject              3678 non-null   object
# dtypes: bool(1), float64(1), int64(5), object(5)
# memory usage: 319.8+ KB

# %%
# Podemos comprobar las ausencias con esta línea de código. 
ucourses.isna().sum()/len(ucourses)
# Eliminación de registros con ausencias.
#df=df.dropna()
# Out:
# course_id              0.0
# course_title           0.0
# url                    0.0
# is_paid                0.0
# price                  0.0
# num_subscribers        0.0
# num_reviews            0.0
# num_lectures           0.0
# level                  0.0
# content_duration       0.0
# published_timestamp    0.0
# subject                0.0
# dtype: float64

# %%
##Diagrama de correlación

# %% [markdown]
# Podemos borrar el id del curso y el url ya que no aportan nada al analisis,  enfocarse en la transformación de las demas variables, organizar el forma de la fecha de publicacion como un datatime para poderlo meter en el analisis, no hay valores faltantes, habia 6 duplicados que se eliminan, podemos depronto ver porque estaban duplicados, profundizar en eso.
# La columna de niveles de level y subject es categorica con esta se puede hacer un muy buen trabajo, meterse en cada categoria para ver las variaciones por año
#
# ojo es importante organizar la columna de las fechas de publicacion para poder trabajar sobre todo con el año

# %%
#Realizar el perfilamiento
profile = ProfileReport(ucourses, title="Perfilamiento de datos")

# %%
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.9.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-10-23 20:28:34.518018&quot;&gt;&lt;title&gt;Perfilamiento de datos&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
#Comprobar cantidad de duplicados
print(ucourses.duplicated().sum())
# Out:
# 6

# %%
# Limpieza de datos 

## El profiling muestra que se tienen 6 datos duplicados 
# Para eliminar el dato duplicado 
ucourses=ucourses.drop_duplicates()

# %%
print(ucourses.duplicated().sum())
# Out:
# 0

# %%
### Transformacion variable tiempo 
ucourses['year'] = pd.DatetimeIndex(ucourses['published_timestamp']).year
# Out:
# <ipython-input-10-28309881fdf5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ucourses['year'] = pd.DatetimeIndex(ucourses['published_timestamp']).year

# %%
ucourses['year']
# Out:
# 0       2017
# 1       2017
# 2       2016
# 3       2017
# 4       2016
#         ...
# 3673    2016
# 3674    2017
# 3675    2015
# 3676    2016
# 3677    2014
# Name: year, Length: 3672, dtype: int64

# %%
## Transformación de datos, como se vio en el profiling no aporta 
ucourses=ucourses.drop(["published_timestamp","url","course_id"],axis=1)
ucourses.head(1)
# Out:
#                          course_title  is_paid  price  num_subscribers  \
# 0  Ultimate Investment Banking Course     True    200             2147
#
#    num_reviews  num_lectures       level  content_duration           subject  \
# 0           23            51  All Levels               1.5  Business Finance
#
#    year
# 0  2017

# %%
ucourses.describe()
# Out:
#              price  num_subscribers   num_reviews  num_lectures  \
# count  3672.000000      3672.000000   3672.000000   3672.000000
# mean     66.102941      3190.586874    156.371460     40.140251
# std      61.035920      9488.105448    936.178649     50.417102
# min       0.000000         0.000000      0.000000      0.000000
# 25%      20.000000       111.750000      4.000000     15.000000
# 50%      45.000000       912.000000     18.000000     25.000000
# 75%      95.000000      2548.750000     67.000000     46.000000
# max     200.000000    268923.000000  27445.000000    779.000000
#
#        content_duration         year
# count       3672.000000  3672.000000
# mean           4.097603  2015.431100
# std            6.057830     1.184731
# min            0.000000  2011.000000
# 25%            1.000000  2015.000000
# 50%            2.000000  2016.000000
# 75%            4.500000  2016.000000
# max           78.500000  2017.000000

# %%
##### Udemy(Los autores actualizand el contenido-> Udemy les dice cuales actualizar) continuamente esta actualizando los curso para brindar un mejor servicio, pero ya que cuentan con un 
#portafolio muy amplio deben seleccionar cuales cursos actualizar, por ello es importante conocer los cursos más populares

# %%
##### Transformación ahora para las variables categoricas

# %%
ucourses['subject'].value_counts()
# Out:
# Web Development        1199
# Business Finance       1191
# Musical Instruments     680
# Graphic Design          602
# Name: subject, dtype: int64

# %%
##3 Grafica circular para ver todos los años

# %%
ucourses['year'].value_counts()
# Out:
# 2016    1204
# 2015    1014
# 2017     713
# 2014     490
# 2013     201
# 2012      45
# 2011       5
# Name: year, dtype: int64

# %%
#Diagrama de barras

# %%
#luego podemos meternos dentro de año y ver cuantos subjects hay en un año especifico 
#y_2015=ucourses[ucourses['year']==2015]
#y_2015["subject"].value_counts()

# %%
ucourses["level"].value_counts()
# Out:
# All Levels            1925
# Beginner Level        1268
# Intermediate Level     421
# Expert Level            58
# Name: level, dtype: int64

# %%
## Grafico

# %%
##3 Podriamos hacer un nuevo dataset con los datos que vamos organizando 
df = ucourses.groupby(['year',"subject","level"])[['num_subscribers','num_reviews','num_lectures']].sum().reset_index()
#mirar bien cuales necesitamos incluir

# %%
## Luego podemos montar una grafica por año con esto 
df
# Out:
#     year              subject               level  num_subscribers  \
# 0   2011      Web Development          All Levels           119028
# 1   2012     Business Finance          All Levels             1677
# 2   2012     Business Finance      Beginner Level             1914
# 3   2012     Business Finance  Intermediate Level               29
# 4   2012       Graphic Design          All Levels           100649
# ..   ...                  ...                 ...              ...
# 81  2017  Musical Instruments  Intermediate Level            22636
# 82  2017      Web Development          All Levels           275854
# 83  2017      Web Development      Beginner Level           293104
# 84  2017      Web Development        Expert Level             1047
# 85  2017      Web Development  Intermediate Level            65734
#
#     num_reviews  num_lectures
# 0          4041           574
# 1           148            63
# 2           268            89
# 3             2             7
# ...

# %%
##### Enriquecimiento de los datos 
top_course = ucourses.sort_values(by='num_subscribers', ascending=False)[:10]
figure = plt.figure(figsize=(10,6))
sns.barplot(y=top_course.course_title, x=top_course.num_subscribers)
plt.xticks()
plt.xlabel('num_subscribers')
plt.ylabel('Course_title')
plt.title('The Most Popular Courses')
plt.show()

# %%
##rs = nursing[['high_salary', 'Rural']].value_counts().reset_index()

# %%
pdf= top_course[['is_paid', 'subject']].value_counts().reset_index()

# %%
pdf
# Out:
#    is_paid              subject  0
# 0    False      Web Development  5
# 1     True      Web Development  4
# 2    False  Musical Instruments  1

# %%
#Top 30 Most Popular Courses Reviews by num_reviews
top_course2 = ucourses.sort_values(by='content_duration', ascending=False)[:10]
figure = plt.figure(figsize=(10,6))
sns.barplot(y=top_course2.course_title, x=top_course2.content_duration)
plt.xticks()
plt.xlabel('content_duration')
plt.ylabel('Course_title')
plt.title('The Most Popular Courses Reviews')
plt.show()

# %%
pdf2= top_course2[['is_paid', 'subject']].value_counts().reset_index()

# %%
pdf2
# Out:
#    is_paid           subject  0
# 0     True   Web Development  4
# 1     True  Business Finance  3
# 2     True    Graphic Design  3

# %%
## Analisis comparativo entre lo que suceda con reviews y lectures

# %%
# Segun lo encontrado en el analisis posterior se quiere conocer de manera detallada la correlacion 
# de las variables que más se destacaron 

## Para la seleccion de variables volver a mirar el diagrama de correlación asi ya este en el profiling 
##pero con las más interesantes para hacerlo llamativo 
Data1= ucourses[['is_paid','price','num_subscribers','num_reviews','num_lectures','content_duration','subject']] 
cor = ucourses.corr() 
sns.heatmap(cor, square = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### Para los modelos de predicción
# 1. Regresion lineal multiple >
# 2. Random forest x
# 3. Clustering >

# %%
#### 
#Linear Regression
# Se selecciona la variable objetivo, en este caso "num_subscribers".
Y=ucourses['num_lectures']
#Variables predictoras 
X=ucourses["content_duration"].values.reshape(-1, 1)

# %%
# Se realiza la división entrenamiento - test. Se deja 20% de los datos para el test.
X_train, X_test, Y_train, Y_test = train_test_split( X, Y, test_size=0.2, random_state=0)

# %%
##### Distribución luego del split 
print("Number of instances in training set: ", len(X_train))
print("Number of instances in testing set: ", len(X_test))
# Out:
# Number of instances in training set:  2937
# Number of instances in testing set:  735

# %%
## Mirar la distribución ..... OJO

# %%
# 3. Construcción del modelo 

# Primero se crea el objeto para construir el modelo
modelo_regresion = LinearRegression()
# Podemos verificar que lo hemos construido.
modelo_regresion
# Out:
# LinearRegression()

# %%
# Ajustar el modelo con los datos de entrenamiento
modelo_regresion.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
# Predicciones del modelo sobre el conjunto de entrenamiento.
y_pred = modelo_regresion.predict(X_train)

# %%
# 4. Evaluación del modelo 

# Que tan bien se desempeña el modelo, como se ajustan los datos
# Mean-Squared-Error(MSE). Error medio cuadrático  ---> Varianza (Se busca que sea lo menor posible)
# Mean-Absolute-Error(MAE). Error absoluto medio   ---> Desviación absoluta promedio 
# R² or Coeficiente de determinación ---> Se busca que sea cercano a 1 

# Se obtienen las métricas a partir de la predicción y la base de evaluación (valores reales).
print("MSE: %.2f" % mean_squared_error(Y_train, y_pred, squared=False))
print("MAE: %.2f" % mean_absolute_error(Y_train, y_pred))
print('R²: %.2f' % r2_score(Y_train, y_pred))

## un R2 cercano a 1 es overt y cercano a 0 under
## Si le saco la raiz al MSE puedo decir que en promedio me equivoco o varia entre el valor que me de
# Out:
# MSE: 31.27
# MAE: 15.78
# R²: 0.63

# %%
# 5. Interpretacion del modelo

# Ajustar el modelo para ver el reporte
model = sm.OLS(Y, X).fit() ## sm.OLS(output, input)
# Mostrar las estadísticas del modelo
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:           num_lectures   R-squared (uncentered):                   0.754
# Model:                            OLS   Adj. R-squared (uncentered):              0.754
# Method:                 Least Squares   F-statistic:                          1.126e+04
# Date:                Mon, 25 Oct 2021   Prob (F-statistic):                        0.00
# Time:                        21:10:27   Log-Likelihood:                         -17931.
# No. Observations:                3672   AIC:                                  3.586e+04
# Df Residuals:                    3671   BIC:                                  3.587e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
## Para sacar resultados de la tabla 
print('coefficient of determination:', model.rsquared)
print('adjusted coefficient of determination:', model.rsquared_adj)
print('regression coefficients:', model.params) ## B0,b1,b2
# Out:
# coefficient of determination: 0.7542005132610146
# adjusted coefficient of determination: 0.7541335561684679
# regression coefficients: x1    7.65259
# dtype: float64

# %%
#Como guardar el modelo....esta en estudio
#X.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-901c1061bf7c> in <module>
# ----> 1 X.columns
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %%
list(zip(X.columns,modelo.coef_))

# %%
#import pickle

#nombre='UdemyStudy.sav'
#pickle.dump(modelo, open(nombre, 'wb'))

# %%
#modelo_cargado=pickle.load(open(nombre, 'rb'))

# %%
#list(zip(X.columns,modelo_cargado.coef_))

# %%
## INTENTAR HACERLA POLINOMIAL O MULTIPLE

# %%
########### Segundo metodo

# %%
from sklearn.cluster import KMeans

# %%
chosen_features = ['num_lectures', 'num_subscribers', 'num_reviews']
x = ucourses.loc[:, chosen_features].values
x_ave = np.mean(x, axis=0)
x_rng = np.ptp(x, axis=0)
x_rng_std = np.divide(np.subtract(x, x_ave), x_rng)
kmeans = KMeans(n_clusters=4, init = 'random', algorithm = 'elkan').fit(x_rng_std)
x = x_rng_std[:, [0]].reshape(-1,)
y = x_rng_std[:, [1]].reshape(-1,)
z = x_rng_std[:, [2]].reshape(-1,)
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111, projection='3d')
ucourses['labels'] = kmeans.labels_
ax.scatter(x, y, z, c = kmeans.labels_, s = 70)
plt.title('Clusters of courses')
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z, c = ucourses['subject'].map({k:i for i,k in enumerate(ucourses['subject'].unique().tolist())}), s = 70)
plt.show()

# %%
for i in sorted(ucourses['labels'].unique()):
    vals = ucourses[ucourses['labels'] == i]
    vals = ucourses.loc[:, chosen_features].values
    print(f'Centers of the cluster {i+1}')
    print(*chosen_features)
    print(*(np.mean(vals, axis = 0).round(3)), sep = '  ')
    print()
# Out:
# Centers of the cluster 1
# num_lectures num_subscribers num_reviews
# 40.14  3190.587  156.371
#
# Centers of the cluster 2
# num_lectures num_subscribers num_reviews
# 40.14  3190.587  156.371
#
# Centers of the cluster 3
# num_lectures num_subscribers num_reviews
# 40.14  3190.587  156.371
#
# Centers of the cluster 4
# num_lectures num_subscribers num_reviews
# 40.14  3190.587  156.371

# %% [markdown]
# - The common pattern and structure of the data can be observed through clutering and analysis of the clusters gained, three features for more convenient visualization were chosen, which are: number of lectures, subscribers and reviews.
#
# - Clusters can be interpreted with respect to popularity - number of subscribers and reviews, also, it may be noticed that not the most expensive courses are the most popular ones.
